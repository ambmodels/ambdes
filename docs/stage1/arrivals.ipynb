# %% [markdown]
# # Arrivals configuration

# %%
import pandas as pd

# %%
def validate_arrivals_csv()

# %%
data = pd.read_csv("data/arrivals_conveyed.csv")
data["area"] = "southwest"
data[["area", "day", "category", "conveyed", "count"]].to_csv("data/arrivals_conveyed.csv", index=False)

# %%
data = pd.read_csv("data/arrivals.csv")
data["area"] = "southwest"
data["conveyed"] = "all"
data[["area", "day", "category", "conveyed", "count"]]
data[["area", "day", "category", "conveyed", "count"]].to_csv("data/arrivals.csv", index=False)
